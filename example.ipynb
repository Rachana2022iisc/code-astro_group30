# %% [markdown]
# # RA/DEC in any format

# %% [raw]
# Co-ordinates of the sources you want to predict: ra, dec can be given in any format (hhmmss+-ddmmss) or (degree+-degree)
# #https://simbad.u-strasbg.fr/simbad/sim-fbasic

# %% [raw]
# `model_file` should contain the path to the trained `.joblib` file. You can either generate this file by running the machine-learning training code "trained_model.ipynb" once or download the pre-trained `.joblib` file from Zenodo.

# %%
from predict_sdss_stellar_class_1 import predict_sdss_coordinates

ra = "09h26m53.2549s"
dec = "+37d37m32.5018s"
search_radius = 1.0
result = predict_sdss_coordinates(
    ra=ra,
    dec=dec,
    radius_arcsec=search_radius,
    model_file="<path>/stellar_class_model.joblib"
)

result
